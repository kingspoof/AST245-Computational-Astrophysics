# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_values = [100, 1000, 10000, 100000, 1000000]
direct_times = np.array([0, 1, 146, 14802, 1613442])
tree_building = np.array([0, 0, 2, 22, 299])
tree_times = np.array([0, 0, 1, 9, 215])
total_tree = tree_building + tree_times



plt.plot(n_values, direct_times, label='Direct Solver', marker='o')
plt.plot(n_values, total_tree, label='Tree Solver', marker='o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Planets')
plt.ylabel('Time (ms)')
plt.title('Performance Comparison of Direct vs Tree-based Solver')
plt.legend()
plt.grid(True)
plt.show()


plt.plot(n_values, direct_times, label='Direct Solver', marker='o')
plt.plot(n_values, total_tree, label='Tree Solver', marker='o')
plt.xlabel('Number of Planets')
plt.ylabel('Time (ms)')
plt.title('Performance Comparison of Direct vs Tree-based Solver')
plt.legend()
plt.grid(True)
plt.show()

# %%
# comparison in values when using different opening values
values = np.array([
    [0.01,1.2451e-06,3611], [0.02,1.72486e-05,3113], [0.03,5.78681e-05,2419],[0.04,0.000131201,1981],[0.05,0.000232523,1692],[0.06,0.000373254,1431],[0.07,0.000552557,1250],[0.08,0.000756063,1124],[0.09,0.000997087,1031],[0.1,0.0012665,955],[0.11,0.00159494,894],[0.12,0.00197895,840],[0.13,0.00239969,821],[0.14,0.00285891,772],[0.15,0.00335203,764],[0.16,0.00388617,728],[0.17,0.00450826,696],[0.18,0.00514135,677],[0.19,0.00584376,661],[0.2,0.00656447,666],[0.21,0.00737642,635],[0.22,0.00834683,655],[0.23,0.00926382,622],[0.24,0.0103303,596],[0.25,0.0114975,596],[0.26,0.01262,583],[0.27,0.0137664,574],[0.28,0.0151307,567],[0.29,0.016356,565],[0.3,0.0177809,560],[0.31,0.0193445,563],[0.32,0.0209715,558],[0.33,0.0227466,555],[0.34,0.0244406,545],[0.35,0.0263385,541],[0.36,0.0285481,543],[0.37,0.03039,540],[0.38,0.0325388,532],[0.39,0.0347189,532],[0.4,0.0372704,549],[0.41,0.0395041,548],[0.42,0.0421166,527],[0.43,0.0450095,524],[0.44,0.0478522,521],[0.45,0.0505492,518],[0.46,0.0535821,519],[0.47,0.0566023,518],[0.48,0.0598326,516],[0.49,0.0634469,522],[0.5,0.0671345,515],[0.51,0.0704596,513],[0.52,0.0749402,509],[0.53,0.0791073,526],[0.54,0.0832086,510],[0.55,0.0878254,509],[0.56,0.0928594,516],[0.57,0.097185,517],[0.58,0.101647,507],[0.59,0.106654,517],[0.6,0.110792,503],[0.61,0.114808,501],[0.62,0.11888,503],[0.63,0.123309,497],[0.64,0.127408,498],[0.65,0.132315,504],[0.66,0.136019,504],[0.67,0.143226,503],[0.68,0.149307,507],[0.69,0.154278,501],[0.7,0.159976,497],[0.71,0.166601,499],[0.72,0.174307,507],[0.73,0.182186,503],[0.74,0.187702,504],[0.75,0.194394,507],[0.76,0.202618,506],[0.77,0.209068,501],[0.78,0.215411,506],[0.79,0.223582,498],[0.8,0.230712,501],[0.81,0.237941,504],[0.82,0.248276,498],[0.83,0.257649,497],[0.84,0.264594,502],[0.85,0.274118,504],[0.86,0.283186,501],[0.87,0.294068,485],[0.88,0.303343,500],[0.89,0.315216,491],[0.9,0.326272,483],[0.91,0.338965,486],[0.92,0.350028,482],[0.93,0.363078,498],[0.94,0.373106,503],[0.95,0.385593,488],[0.96,0.394407,495],[0.97,0.408606,481],[0.98,0.420805,496],[0.99,0.431432,481],
])

values[:,2] /= 10000

# Create figure with two horizontal subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Deviation vs Opening Angle (no normalization)
ax1.plot(values[:,0], values[:,1], label='Relative Deviation', color='#1f77b4')
ax1.set_xlabel('Opening Angle (θ)', fontsize=12)
ax1.set_ylabel('Relative Deviation', fontsize=12)
ax1.set_title('Opening Angle vs Accuracy of Tree Code')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
#ax1.text(0.5, 0.95, 'Lower deviation indicates better accuracy of tree approximation', 
#         transform=ax1.transAxes, fontsize=9, verticalalignment='top',
#         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# Plot 2: Computation Time vs Opening Angle (no normalization)
ax2.plot(values[:,0], values[:,2], label='Computation Time (ms)', color='#ff7f0e')
ax2.set_xlabel('Opening Angle (θ)', fontsize=12)
ax2.set_ylabel('Computation Time (ms)', fontsize=12)
ax2.set_title('Opening Angle vs Computational Cost', fontsize=13)
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=10)
#ax2.text(0.5, 0.95, 'Larger opening angles reduce tree depth, decreasing computation time', 
#         transform=ax2.transAxes, fontsize=9, verticalalignment='top',
#         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))

plt.tight_layout()
plt.show()


# Create figure with two horizontal subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Deviation vs Opening Angle (no normalization)
ax1.semilogy(values[:,0], values[:,1], label='Relative Deviation', color='#1f77b4')
ax1.set_xlabel('Opening Angle (θ)', fontsize=12)
ax1.set_ylabel('Relative Deviation', fontsize=12)
ax1.set_title('Opening Angle vs Accuracy of Tree Code')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
#ax1.text(0.5, 0.95, 'Lower deviation indicates better accuracy of tree approximation', 
#         transform=ax1.transAxes, fontsize=9, verticalalignment='top',
#         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# Plot 2: Computation Time vs Opening Angle (no normalization)
ax2.semilogy(values[:,0], values[:,2], label='Computation Time (ms)', color='#ff7f0e')
ax2.set_xlabel('Opening Angle (θ)', fontsize=12)
ax2.set_ylabel('Computation Time (ms)', fontsize=12)
ax2.set_title('Opening Angle vs Computational Cost', fontsize=13)
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=10)
#ax2.text(0.5, 0.95, 'Larger opening angles reduce tree depth, decreasing computation time', 
#         transform=ax2.transAxes, fontsize=9, verticalalignment='top',
#         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))

plt.tight_layout()
plt.show()
