# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the used properties
N = 10000
v0 = 1 #
dx = 1/N # because the cells have to be 1 dx apart from each other
dt = dx/(2*v0)

steps_per_evolution = 2 * (N + 1)
